# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(color_codes=True)

# %%
desktops = pd.read_csv("../data/desktops.csv")
notebooks = pd.read_csv("../data/notebooks.csv")
df = pd.concat([desktops, notebooks])
df.head()
# Out:
#    p_id category_name  p_source_id  \
# 0  4267      desktops    100109543
# 1  4274      desktops    100076325
# 2  4287      desktops      1480615
# 3  4295      desktops    100120419
# 4  4299      desktops    100036768
#
#                                           title   price   brand  rating  \
# 0                     PULSER Advanced 98 черный  387860  PULSER      10
# 1        Acer Nitro N50-600 DG.E0HMC.02A черный  299990    Acer      10
# 2  Acer ASPIRE C22-865 DQ.BBRMC.002 серебристый  243620    Acer      10
# 3                     PULSER Advanced 90 черный  216366  PULSER       9
# 4                     PULSER Standard 63 черный  173378  PULSER      10
#
#    reviews_quantity                  cpu  cpu_rate   hertz  cores  \
# 0                 5  intel сore i5-9400f        56  2900.0    6.0
# 1                 1   intel core i3-8400        65  2800.0    6.0
# 2                 2  intel core i3 8130u        59  2200.0    2.0
# 3                 5  intel сore i3 9100f        55  3600.0    4.0
# 4                 3  intel core i3 9100f        55  3600.0    4.0
#
#                           gpu  gpu_rate  ram ram_type    ssd  drive_size  \
# 0          gtx 1660 super 6gb      77.0  6.0      NaN   True       480.0
# 1  nvidia geforce gtx 1050 ti      54.0  8.0      NaN   True      1000.0
# 2      intel uhd graphics 620      20.0  4.0      NaN  False      1000.0
# 3         geforce gtx 1050 ti      57.0  8.0      NaN   True       480.0
# 4      geforce gtx 1050 d5 2g      54.0  8.0      NaN   True       240.0
#
#                                                  url
# 0  https://kaspi.kz/shop/p/pulser-advanced-98-che...
# 1  https://kaspi.kz/shop/p/acer-nitro-n50-600-dg-...
# 2  https://kaspi.kz/shop/p/acer-aspire-c22-865-dq...
# 3  https://kaspi.kz/shop/p/pulser-advanced-90-che...
# 4  https://kaspi.kz/shop/p/pulser-standard-63-che...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 406 entries, 0 to 231
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   p_id              406 non-null    int64
#  1   category_name     406 non-null    object
#  2   p_source_id       406 non-null    int64
#  3   title             406 non-null    object
#  4   price             406 non-null    int64
#  5   brand             406 non-null    object
#  6   rating            406 non-null    int64
#  7   reviews_quantity  406 non-null    int64
#  8   cpu               406 non-null    object
#  9   cpu_rate          406 non-null    int64
#  10  hertz             389 non-null    float64
#  11  cores             374 non-null    float64
#  12  gpu               406 non-null    object
#  13  gpu_rate          406 non-null    float64
#  14  ram               398 non-null    float64
#  15  ram_type          217 non-null    object
#  16  ssd               384 non-null    object
#  17  drive_size        403 non-null    float64
#  18  url               406 non-null    object
# dtypes: float64(5), int64(6), object(8)
# memory usage: 63.4+ KB

# %%
df.describe()
# Out:
#                p_id   p_source_id          price      rating  \
# count    406.000000  4.060000e+02     406.000000  406.000000
# mean    7042.135468  5.461833e+07  327049.588670    4.586207
# std     3237.889379  4.926222e+07  170069.553967    4.821373
# min     4229.000000  1.304700e+06   89360.000000    0.000000
# 25%     4567.250000  1.307560e+06  199900.000000    0.000000
# 50%     5267.000000  1.000085e+08  288195.000000    0.000000
# 75%     8997.250000  1.000837e+08  418677.000000   10.000000
# max    14055.000000  1.002135e+08  998000.000000   10.000000
#
#        reviews_quantity    cpu_rate        hertz       cores    gpu_rate  \
# count        406.000000  406.000000   389.000000  374.000000  406.000000
# mean           2.652709   64.830049  2431.704370    3.711230   33.750000
# std            6.808497    9.416989   744.187579    1.390135   19.593106
# min            0.000000   22.000000  1000.000000    2.000000   12.000000
# 25%            0.000000   59.000000  1800.000000    2.000000   20.000000
# 50%            0.000000   66.000000  2300.000000    4.000000   21.000000
# 75%            2.000000   69.000000  3000.000000    4.000000   49.000000
# max           70.000000   93.000000  4000.000000    8.000000   91.000000
#
#               ram   drive_size
# count  398.000000   403.000000
# mean     5.788945   776.883375
# std      1.965875   361.500210
# min      0.000000    64.000000
# 25%      4.000000   500.000000
# 50%      6.000000  1000.000000
# 75%      8.000000  1000.000000
# max      8.000000  2480.000000

# %%
sns.distplot(df.price, color="r")
